# %% [markdown]
# # pandas

# %%
import numpy as np

# %%
import pandas as pd

# %%
array1=np.array([[1,2,3,4],[5,6,7,8]])
a1=pd.DataFrame(array1)
a1
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
a2=pd.DataFrame([[1,2,34,5],[3,45,67,8]],columns=['A','B','C','D'])
a2
# Out:
#    A   B   C  D
# 0  1   2  34  5
# 1  3  45  67  8

# %%
a3=pd.DataFrame([1,2,3,4],columns=['A'])
a3
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
a3=pd.DataFrame({
    "Name":['swapna','tunia','paro','parbati','puja','narmada','rutu'],
    'Marks':[98,89,97,93,95,94,93],
    'Age':[21,21,22,23,24,23,22]
})
a3
# Out:
#       Name  Marks  Age
# 0   swapna     98   21
# 1    tunia     89   21
# 2     paro     97   22
# 3  parbati     93   23
# 4     puja     95   24
# 5  narmada     94   23
# 6     rutu     93   22

# %%
a3.to_csv('list.csv')

# %%
a3.to_csv("false_indexing remove.csv",index = False)

# %%
a3.head(2)
# Out:
#      Name  Marks  Age
# 0  swapna     98   21
# 1   tunia     89   21

# %%
a3.tail(2)
# Out:
#       Name  Marks  Age
# 5  narmada     94   23
# 6     rutu     93   22

# %%
a3.describe()
# Out:
#            Marks        Age
# count   7.000000   7.000000
# mean   94.142857  22.285714
# std     2.968084   1.112697
# min    89.000000  21.000000
# 25%    93.000000  21.500000
# 50%    94.000000  22.000000
# 75%    96.000000  23.000000
# max    98.000000  24.000000

# %%
a5=pd.read_excel('Book1.xlsx')
a5
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\_optional.py:158, in import_optional_dependency(name, extra, min_version, errors)
#     157 try:
# --> 158     module = importlib.import_module(name)
#     159 except ImportError as err:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# ...

# %%
a6=pd.read_csv('false_indexing remove.csv')
a6
# Out:
#       Name  Marks  Age
# 0   swapna     98   21
# 1    tunia     89   21
# 2     paro     97   22
# 3  parbati     93   23
# 4     puja     95   24
# 5  narmada     94   23
# 6     rutu     93   22

# %%
a6['Name']
# Out:
# 0     swapna
# 1      tunia
# 2       paro
# 3    parbati
# 4       puja
# 5    narmada
# 6       rutu
# Name: Name, dtype: str

# %%
a6['Name'][0]
# Out:
# 'swapna'

# %%
a6['Name'][1]='hii'

# %%
a6
# Out:
#       Name  Marks  Age
# 0   swapna     98   21
# 1    tunia     89   21
# 2     paro     97   22
# 3  parbati     93   23
# 4     puja     95   24
# 5  narmada     94   23
# 6     rutu     93   22

# %%
a6.index=['A','B','C','D','E','F','G']

# %%
a6
# Out:
#       Name  Marks  Age
# A   swapna     98   21
# B    tunia     89   21
# C     paro     97   22
# D  parbati     93   23
# E     puja     95   24
# F  narmada     94   23
# G     rutu     93   22

# %%
a3=pd.DataFrame({
    "Name":['swapna','tunia','paro'],
    'age':[23,56,89]
})
a3
# Out:
#      Name  age
# 0  swapna   23
# 1   tunia   56
# 2    paro   89

# %%
a4=pd.DataFrame([[1,2],[4,7],[8,9]])
a4
# Out:
#    0  1
# 0  1  2
# 1  4  7
# 2  8  9

# %%
a4.describe()
# Out:
#               0         1
# count  3.000000  3.000000
# mean   4.333333  6.000000
# std    3.511885  3.605551
# min    1.000000  2.000000
# 25%    2.500000  4.500000
# 50%    4.000000  7.000000
# 75%    6.000000  8.000000
# max    8.000000  9.000000

# %%
a4.corr()
# Out:
#           0         1
# 0  1.000000  0.947697
# 1  0.947697  1.000000

# %%
a4.count()
# Out:
# 0    3
# 1    3
# dtype: int64

# %%
a4.median()
# Out:
# 0    4.0
# 1    7.0
# dtype: float64
